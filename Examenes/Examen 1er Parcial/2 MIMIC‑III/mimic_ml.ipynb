# %% [markdown]
# # Cuadernillo MIMIC-III: integracion, diccionario y preparacion para ML
#
# Este cuadernillo esta disenado para:
#
# 1. Entender de que trata el dataset MIMIC-III y sus tablas principales.
# 2. Construir una tabla de columnas por dataset con significado practico.
# 3. Integrar tablas clinicas en un dataset analitico.
# 4. Transformar variables a formato numerico y documentar que se transforma y por que.
# 5. Dejar listo un pipeline para ejercicios de regresion, clasificacion y redes neuronales.
#
# > Nota: algunas tablas (por ejemplo `CHARTEVENTS`) son muy grandes. Este cuadernillo usa una estrategia de agregacion y seleccion de variables para mantener el flujo usable en un equipo personal.

# %% [markdown]
# ## 1) Contexto general del dataset
#
# **MIMIC-III** (Medical Information Mart for Intensive Care) es una base de datos clinica de pacientes de UCI que incluye:
#
# - Datos demograficos (`PATIENTS`).
# - Episodios de hospitalizacion (`ADMISSIONS`).
# - Estancias en UCI (`ICUSTAYS`).
# - Eventos clinicos temporales (monitorizacion, laboratorio, medicamentos, microbiologia, notas, procedimientos, etc.).
#
# ### Claves relacionales principales
#
# - `subject_id`: paciente.
# - `hadm_id`: ingreso hospitalario.
# - `icustay_id`: estancia en UCI.
#
# ### Tipos de problemas de ML que permite
#
# - **Clasificacion**: mortalidad hospitalaria (`hospital_expire_flag`), readmision, sepsis, etc.
# - **Regresion**: duracion de estancia (LOS), consumo de recursos, costos proxy.
# - **Modelos secuenciales / redes neuronales**: series temporales por hora en UCI (chartevents/labevents).
#
# ### Consideraciones tecnicas
#
# - Datos longitudinales con timestamps.
# - Fuerte presencia de valores faltantes.
# - Variables categoricas y textuales extensas.
# - Tablas muy grandes requieren agregacion, muestreo o procesamiento incremental.

# %%
from pathlib import Path
import pandas as pd
import numpy as np
from IPython.display import display, Markdown

BASE_DIR = Path('.')
csv_files = sorted(BASE_DIR.glob('*.csv'))
len(csv_files), [f.name for f in csv_files[:8]]
# Out:
# (26,
#  ['ADMISSIONS.csv',
#   'CALLOUT.csv',
#   'CAREGIVERS.csv',
#   'CHARTEVENTS.csv',
#   'CPTEVENTS.csv',
#   'D_CPT.csv',
#   'D_ICD_DIAGNOSES.csv',
#   'D_ICD_PROCEDURES.csv'])

# %% [markdown]
# ## 2) Tabla de columnas por dataset (diccionario practico)
#
# En esta seccion, para **cada CSV** se genera una tabla con:
#
# - nombre de columna,
# - tipo de variable inferido,
# - descripcion (heuristica basada en nomenclatura MIMIC).
#
# Esto sirve como un diccionario util para el analisis. Para un significado clinico formal al 100%, se recomienda contrastar con la documentacion oficial de MIMIC-III.

# %%
# Diccionario base de descripciones por nombres comunes
desc_map = {
    'row_id': 'Identificador interno de la fila en la tabla.',
    'subject_id': 'Identificador unico del paciente.',
    'hadm_id': 'Identificador del ingreso hospitalario.',
    'icustay_id': 'Identificador de la estancia en UCI.',
    'itemid': 'Codigo del item clinico (se mapea con tablas D_*).',
    'cgid': 'Identificador del cuidador/profesional que registro el dato.',
    'charttime': 'Timestamp clinico del evento/medicion.',
    'storetime': 'Timestamp de almacenamiento del registro.',
    'starttime': 'Tiempo de inicio de evento.',
    'endtime': 'Tiempo de fin de evento.',
    'admittime': 'Fecha/hora de admision hospitalaria.',
    'dischtime': 'Fecha/hora de alta hospitalaria.',
    'deathtime': 'Fecha/hora de fallecimiento (si aplica).',
    'intime': 'Inicio de estancia en UCI.',
    'outtime': 'Fin de estancia en UCI.',
    'dob': 'Fecha de nacimiento.',
    'dod': 'Fecha de defuncion.',
    'gender': 'Sexo del paciente.',
    'age': 'Edad del paciente (derivada normalmente, no siempre viene directa).',
    'los': 'Length of stay (duracion de estancia).',
    'value': 'Valor textual original de la observacion.',
    'valuenum': 'Valor numerico de la observacion.',
    'valueuom': 'Unidad del valor.',
    'flag': 'Bandera del laboratorio (normal/anormal, etc.).',
    'label': 'Nombre legible del codigo/variable.',
    'category': 'Categoria del evento/nota/item.',
    'dbsource': 'Sistema de origen (CareVue/MetaVision).',
    'diagnosis': 'Diagnostico principal de admision/episodio.',
    'hospital_expire_flag': 'Indicador de mortalidad hospitalaria (target de clasificacion).',
    'admission_type': 'Tipo de admision (electiva, emergencia, etc.).',
    'admission_location': 'Origen de admision.',
    'discharge_location': 'Destino al alta.',
    'insurance': 'Tipo de seguro.',
    'language': 'Idioma del paciente.',
    'religion': 'Religion registrada.',
    'marital_status': 'Estado civil.',
    'ethnicity': 'Grupo etnico registrado.',
    'drug': 'Nombre del medicamento.',
    'route': 'Via de administracion del medicamento.',
    'text': 'Texto libre (notas clinicas).',
    'icd9_code': 'Codigo ICD-9 diagnostico/procedimiento.'
}

def infer_kind(col):
    c = col.lower()
    if c.endswith('time') or c in {'dob','dod','chartdate','startdate','enddate'}:
        return 'fecha/hora'
    if c.endswith('_id') or c in {'itemid','cgid','row_id'}:
        return 'identificador'
    if c in {'valuenum','los','hospital_expire_flag','expire_flag'}:
        return 'numerica'
    if c in {'value','label','category','diagnosis','drug','text','ethnicity'}:
        return 'texto/categorica'
    return 'mixta o por revisar'

def describe_col(col):
    c = col.lower()
    if c in desc_map:
        return desc_map[c]
    if c.endswith('_id'):
        return 'Identificador relacional para unir tablas.'
    if 'time' in c or c in {'chartdate','startdate','enddate'}:
        return 'Variable temporal del proceso clinico.'
    if c.startswith('is_') or c.endswith('_flag'):
        return 'Variable binaria indicadora.'
    return 'Descripcion inferida: revisar documentacion oficial para definicion exacta.'

schema_tables = {}
for f in csv_files:
    cols = pd.read_csv(f, nrows=0).columns.tolist()
    schema_df = pd.DataFrame({
        'columna': cols,
        'tipo_inferido': [infer_kind(c) for c in cols],
        'descripcion': [describe_col(c) for c in cols]
    })
    schema_tables[f.stem] = schema_df

for name, sdf in schema_tables.items():
    display(Markdown(f'### {name}'))
    display(sdf)
# Out:
# ### ADMISSIONS
#                  columna        tipo_inferido  \
# 0                 row_id        identificador
# 1             subject_id        identificador
# 2                hadm_id        identificador
# 3              admittime           fecha/hora
# 4              dischtime           fecha/hora
# 5              deathtime           fecha/hora
# 6         admission_type  mixta o por revisar
# 7     admission_location  mixta o por revisar
# 8     discharge_location  mixta o por revisar
# 9              insurance  mixta o por revisar
# 10              language  mixta o por revisar
# 11              religion  mixta o por revisar
# 12        marital_status  mixta o por revisar
# 13             ethnicity     texto/categorica
# 14             edregtime           fecha/hora
# 15             edouttime           fecha/hora
# 16             diagnosis     texto/categorica
# 17  hospital_expire_flag             numerica
# 18  has_chartevents_data  mixta o por revisar
#
#                                           descripcion
# 0       Identificador interno de la fila en la tabla.
# 1                   Identificador unico del paciente.
# 2             Identificador del ingreso hospitalario.
# 3                Fecha/hora de admision hospitalaria.
# 4                    Fecha/hora de alta hospitalaria.
# 5            Fecha/hora de fallecimiento (si aplica).
# 6      Tipo de admision (electiva, emergencia, etc.).
# 7                                 Origen de admision.
# 8                                    Destino al alta.
# 9                                     Tipo de seguro.
# 10                               Idioma del paciente.
# 11                               Religion registrada.
# 12                                      Estado civil.
# 13                           Grupo etnico registrado.
# 14             Variable temporal del proceso clinico.
# 15             Variable temporal del proceso clinico.
# 16        Diagnostico principal de admision/episodio.
# 17  Indicador de mortalidad hospitalaria (target d...
# 18  Descripcion inferida: revisar documentacion of...
# ### CALLOUT
#                    columna        tipo_inferido  \
# 0                   row_id        identificador
# 1               subject_id        identificador
# 2                  hadm_id        identificador
# 3            submit_wardid  mixta o por revisar
# 4          submit_careunit  mixta o por revisar
# 5              curr_wardid  mixta o por revisar
# 6            curr_careunit  mixta o por revisar
# 7           callout_wardid  mixta o por revisar
# 8          callout_service  mixta o por revisar
# 9             request_tele  mixta o por revisar
# 10            request_resp  mixta o por revisar
# 11           request_cdiff  mixta o por revisar
# 12            request_mrsa  mixta o por revisar
# 13             request_vre  mixta o por revisar
# 14          callout_status  mixta o por revisar
# 15         callout_outcome  mixta o por revisar
# 16        discharge_wardid  mixta o por revisar
# 17      acknowledge_status  mixta o por revisar
# 18              createtime           fecha/hora
# 19              updatetime           fecha/hora
# 20         acknowledgetime           fecha/hora
# 21             outcometime           fecha/hora
# 22    firstreservationtime           fecha/hora
# 23  currentreservationtime           fecha/hora
#
#                                           descripcion
# 0       Identificador interno de la fila en la tabla.
# 1                   Identificador unico del paciente.
# 2             Identificador del ingreso hospitalario.
# 3   Descripcion inferida: revisar documentacion of...
# 4   Descripcion inferida: revisar documentacion of...
# 5   Descripcion inferida: revisar documentacion of...
# 6   Descripcion inferida: revisar documentacion of...
# 7   Descripcion inferida: revisar documentacion of...
# 8   Descripcion inferida: revisar documentacion of...
# 9   Descripcion inferida: revisar documentacion of...
# 10  Descripcion inferida: revisar documentacion of...
# 11  Descripcion inferida: revisar documentacion of...
# 12  Descripcion inferida: revisar documentacion of...
# 13  Descripcion inferida: revisar documentacion of...
# 14  Descripcion inferida: revisar documentacion of...
# 15  Descripcion inferida: revisar documentacion of...
# 16  Descripcion inferida: revisar documentacion of...
# 17  Descripcion inferida: revisar documentacion of...
# 18             Variable temporal del proceso clinico.
# 19             Variable temporal del proceso clinico.
# 20             Variable temporal del proceso clinico.
# 21             Variable temporal del proceso clinico.
# 22             Variable temporal del proceso clinico.
# 23             Variable temporal del proceso clinico.
# ### CAREGIVERS
#        columna        tipo_inferido  \
# 0       row_id        identificador
# 1         cgid        identificador
# 2        label     texto/categorica
# 3  description  mixta o por revisar
#
#                                          descripcion
# 0      Identificador interno de la fila en la tabla.
# 1  Identificador del cuidador/profesional que reg...
# 2                Nombre legible del codigo/variable.
# 3  Descripcion inferida: revisar documentacion of...
# ### CHARTEVENTS
#          columna        tipo_inferido  \
# 0         row_id        identificador
# 1     subject_id        identificador
# 2        hadm_id        identificador
# 3     icustay_id        identificador
# 4         itemid        identificador
# 5      charttime           fecha/hora
# 6      storetime           fecha/hora
# 7           cgid        identificador
# 8          value     texto/categorica
# 9       valuenum             numerica
# 10      valueuom  mixta o por revisar
# 11       warning  mixta o por revisar
# 12         error  mixta o por revisar
# 13  resultstatus  mixta o por revisar
# 14       stopped  mixta o por revisar
#
#                                           descripcion
# 0       Identificador interno de la fila en la tabla.
# 1                   Identificador unico del paciente.
# 2             Identificador del ingreso hospitalario.
# 3                Identificador de la estancia en UCI.
# 4   Codigo del item clinico (se mapea con tablas D...
# 5              Timestamp clinico del evento/medicion.
# 6           Timestamp de almacenamiento del registro.
# 7   Identificador del cuidador/profesional que reg...
# 8           Valor textual original de la observacion.
# 9                   Valor numerico de la observacion.
# 10                                  Unidad del valor.
# 11  Descripcion inferida: revisar documentacion of...
# 12  Descripcion inferida: revisar documentacion of...
# 13  Descripcion inferida: revisar documentacion of...
# 14  Descripcion inferida: revisar documentacion of...
# ### CPTEVENTS
#              columna        tipo_inferido  \
# 0             row_id        identificador
# 1         subject_id        identificador
# 2            hadm_id        identificador
# 3         costcenter  mixta o por revisar
# 4          chartdate           fecha/hora
# 5             cpt_cd  mixta o por revisar
# 6         cpt_number  mixta o por revisar
# 7         cpt_suffix  mixta o por revisar
# 8      ticket_id_seq  mixta o por revisar
# 9      sectionheader  mixta o por revisar
# 10  subsectionheader  mixta o por revisar
# 11       description  mixta o por revisar
#
#                                           descripcion
# 0       Identificador interno de la fila en la tabla.
# 1                   Identificador unico del paciente.
# 2             Identificador del ingreso hospitalario.
# 3   Descripcion inferida: revisar documentacion of...
# 4              Variable temporal del proceso clinico.
# 5   Descripcion inferida: revisar documentacion of...
# 6   Descripcion inferida: revisar documentacion of...
# 7   Descripcion inferida: revisar documentacion of...
# 8   Descripcion inferida: revisar documentacion of...
# 9   Descripcion inferida: revisar documentacion of...
# 10  Descripcion inferida: revisar documentacion of...
# 11  Descripcion inferida: revisar documentacion of...
# ### D_CPT
#                columna        tipo_inferido  \
# 0               row_id        identificador
# 1             category     texto/categorica
# 2         sectionrange  mixta o por revisar
# 3        sectionheader  mixta o por revisar
# 4      subsectionrange  mixta o por revisar
# 5     subsectionheader  mixta o por revisar
# 6           codesuffix  mixta o por revisar
# 7  mincodeinsubsection  mixta o por revisar
# 8  maxcodeinsubsection  mixta o por revisar
#
#                                          descripcion
# 0      Identificador interno de la fila en la tabla.
# 1                    Categoria del evento/nota/item.
# 2  Descripcion inferida: revisar documentacion of...
# 3  Descripcion inferida: revisar documentacion of...
# 4  Descripcion inferida: revisar documentacion of...
# 5  Descripcion inferida: revisar documentacion of...
# 6  Descripcion inferida: revisar documentacion of...
# 7  Descripcion inferida: revisar documentacion of...
# 8  Descripcion inferida: revisar documentacion of...
# ### D_ICD_DIAGNOSES
#        columna        tipo_inferido  \
# 0       row_id        identificador
# 1    icd9_code  mixta o por revisar
# 2  short_title  mixta o por revisar
# 3   long_title  mixta o por revisar
#
#                                          descripcion
# 0      Identificador interno de la fila en la tabla.
# 1            Codigo ICD-9 diagnostico/procedimiento.
# 2  Descripcion inferida: revisar documentacion of...
# 3  Descripcion inferida: revisar documentacion of...
# ### D_ICD_PROCEDURES
#        columna        tipo_inferido  \
# 0       row_id        identificador
# 1    icd9_code  mixta o por revisar
# 2  short_title  mixta o por revisar
# 3   long_title  mixta o por revisar
#
#                                          descripcion
# 0      Identificador interno de la fila en la tabla.
# 1            Codigo ICD-9 diagnostico/procedimiento.
# 2  Descripcion inferida: revisar documentacion of...
# 3  Descripcion inferida: revisar documentacion of...
# ### D_ITEMS
#         columna        tipo_inferido  \
# 0        row_id        identificador
# 1        itemid        identificador
# 2         label     texto/categorica
# 3  abbreviation  mixta o por revisar
# 4      dbsource  mixta o por revisar
# 5       linksto  mixta o por revisar
# 6      category     texto/categorica
# 7      unitname  mixta o por revisar
# 8    param_type  mixta o por revisar
# 9     conceptid  mixta o por revisar
#
#                                          descripcion
# 0      Identificador interno de la fila en la tabla.
# 1  Codigo del item clinico (se mapea con tablas D...
# 2                Nombre legible del codigo/variable.
# 3  Descripcion inferida: revisar documentacion of...
# 4            Sistema de origen (CareVue/MetaVision).
# 5  Descripcion inferida: revisar documentacion of...
# 6                    Categoria del evento/nota/item.
# 7  Descripcion inferida: revisar documentacion of...
# 8  Descripcion inferida: revisar documentacion of...
# 9  Descripcion inferida: revisar documentacion of...
# ### D_LABITEMS
#       columna        tipo_inferido  \
# 0      row_id        identificador
# 1      itemid        identificador
# 2       label     texto/categorica
# 3       fluid  mixta o por revisar
# 4    category     texto/categorica
# 5  loinc_code  mixta o por revisar
#
#                                          descripcion
# 0      Identificador interno de la fila en la tabla.
# 1  Codigo del item clinico (se mapea con tablas D...
# 2                Nombre legible del codigo/variable.
# 3  Descripcion inferida: revisar documentacion of...
# 4                    Categoria del evento/nota/item.
# 5  Descripcion inferida: revisar documentacion of...
# ### DATETIMEEVENTS
#          columna        tipo_inferido  \
# 0         row_id        identificador
# 1     subject_id        identificador
# 2        hadm_id        identificador
# 3     icustay_id        identificador
# 4         itemid        identificador
# 5      charttime           fecha/hora
# 6      storetime           fecha/hora
# 7           cgid        identificador
# 8          value     texto/categorica
# 9       valueuom  mixta o por revisar
# 10       warning  mixta o por revisar
# 11         error  mixta o por revisar
# 12  resultstatus  mixta o por revisar
# 13       stopped  mixta o por revisar
#
#                                           descripcion
# 0       Identificador interno de la fila en la tabla.
# 1                   Identificador unico del paciente.
# 2             Identificador del ingreso hospitalario.
# 3                Identificador de la estancia en UCI.
# 4   Codigo del item clinico (se mapea con tablas D...
# 5              Timestamp clinico del evento/medicion.
# 6           Timestamp de almacenamiento del registro.
# 7   Identificador del cuidador/profesional que reg...
# 8           Valor textual original de la observacion.
# 9                                   Unidad del valor.
# 10  Descripcion inferida: revisar documentacion of...
# 11  Descripcion inferida: revisar documentacion of...
# 12  Descripcion inferida: revisar documentacion of...
# 13  Descripcion inferida: revisar documentacion of...
# ### DIAGNOSES_ICD
#       columna        tipo_inferido  \
# 0      row_id        identificador
# 1  subject_id        identificador
# 2     hadm_id        identificador
# 3     seq_num  mixta o por revisar
# 4   icd9_code  mixta o por revisar
#
#                                          descripcion
# 0      Identificador interno de la fila en la tabla.
# 1                  Identificador unico del paciente.
# 2            Identificador del ingreso hospitalario.
# 3  Descripcion inferida: revisar documentacion of...
# 4            Codigo ICD-9 diagnostico/procedimiento.
# ### DRGCODES
#          columna        tipo_inferido  \
# 0         row_id        identificador
# 1     subject_id        identificador
# 2        hadm_id        identificador
# 3       drg_type  mixta o por revisar
# 4       drg_code  mixta o por revisar
# 5    description  mixta o por revisar
# 6   drg_severity  mixta o por revisar
# 7  drg_mortality  mixta o por revisar
#
#                                          descripcion
# 0      Identificador interno de la fila en la tabla.
# 1                  Identificador unico del paciente.
# 2            Identificador del ingreso hospitalario.
# 3  Descripcion inferida: revisar documentacion of...
# 4  Descripcion inferida: revisar documentacion of...
# 5  Descripcion inferida: revisar documentacion of...
# 6  Descripcion inferida: revisar documentacion of...
# 7  Descripcion inferida: revisar documentacion of...
# ### ICUSTAYS
#            columna        tipo_inferido  \
# 0           row_id        identificador
# 1       subject_id        identificador
# 2          hadm_id        identificador
# 3       icustay_id        identificador
# 4         dbsource  mixta o por revisar
# 5   first_careunit  mixta o por revisar
# 6    last_careunit  mixta o por revisar
# 7     first_wardid  mixta o por revisar
# 8      last_wardid  mixta o por revisar
# 9           intime           fecha/hora
# 10         outtime           fecha/hora
# 11             los             numerica
#
#                                           descripcion
# 0       Identificador interno de la fila en la tabla.
# 1                   Identificador unico del paciente.
# 2             Identificador del ingreso hospitalario.
# 3                Identificador de la estancia en UCI.
# 4             Sistema de origen (CareVue/MetaVision).
# 5   Descripcion inferida: revisar documentacion of...
# 6   Descripcion inferida: revisar documentacion of...
# 7   Descripcion inferida: revisar documentacion of...
# 8   Descripcion inferida: revisar documentacion of...
# 9                          Inicio de estancia en UCI.
# 10                            Fin de estancia en UCI.
# 11             Length of stay (duracion de estancia).
# ### INPUTEVENTS_CV
#               columna        tipo_inferido  \
# 0              row_id        identificador
# 1          subject_id        identificador
# 2             hadm_id        identificador
# 3          icustay_id        identificador
# 4           charttime           fecha/hora
# 5              itemid        identificador
# 6              amount  mixta o por revisar
# 7           amountuom  mixta o por revisar
# 8                rate  mixta o por revisar
# 9             rateuom  mixta o por revisar
# 10          storetime           fecha/hora
# 11               cgid        identificador
# 12            orderid  mixta o por revisar
# 13        linkorderid  mixta o por revisar
# 14            stopped  mixta o por revisar
# 15          newbottle  mixta o por revisar
# 16     originalamount  mixta o por revisar
# 17  originalamountuom  mixta o por revisar
# 18      originalroute  mixta o por revisar
# 19       originalrate  mixta o por revisar
# 20    originalrateuom  mixta o por revisar
# 21       originalsite  mixta o por revisar
#
#                                           descripcion
# 0       Identificador interno de la fila en la tabla.
# 1                   Identificador unico del paciente.
# 2             Identificador del ingreso hospitalario.
# 3                Identificador de la estancia en UCI.
# 4              Timestamp clinico del evento/medicion.
# 5   Codigo del item clinico (se mapea con tablas D...
# 6   Descripcion inferida: revisar documentacion of...
# 7   Descripcion inferida: revisar documentacion of...
# 8   Descripcion inferida: revisar documentacion of...
# 9   Descripcion inferida: revisar documentacion of...
# 10          Timestamp de almacenamiento del registro.
# 11  Identificador del cuidador/profesional que reg...
# 12  Descripcion inferida: revisar documentacion of...
# 13  Descripcion inferida: revisar documentacion of...
# 14  Descripcion inferida: revisar documentacion of...
# 15  Descripcion inferida: revisar documentacion of...
# 16  Descripcion inferida: revisar documentacion of...
# 17  Descripcion inferida: revisar documentacion of...
# 18  Descripcion inferida: revisar documentacion of...
# 19  Descripcion inferida: revisar documentacion of...
# 20  Descripcion inferida: revisar documentacion of...
# 21  Descripcion inferida: revisar documentacion of...
# ### INPUTEVENTS_MV
#                           columna        tipo_inferido  \
# 0                          row_id        identificador
# 1                      subject_id        identificador
# 2                         hadm_id        identificador
# 3                      icustay_id        identificador
# 4                       starttime           fecha/hora
# 5                         endtime           fecha/hora
# 6                          itemid        identificador
# 7                          amount  mixta o por revisar
# 8                       amountuom  mixta o por revisar
# 9                            rate  mixta o por revisar
# 10                        rateuom  mixta o por revisar
# 11                      storetime           fecha/hora
# 12                           cgid        identificador
# 13                        orderid  mixta o por revisar
# 14                    linkorderid  mixta o por revisar
# 15              ordercategoryname  mixta o por revisar
# 16     secondaryordercategoryname  mixta o por revisar
# 17  ordercomponenttypedescription  mixta o por revisar
# 18       ordercategorydescription  mixta o por revisar
# 19                  patientweight  mixta o por revisar
# 20                    totalamount  mixta o por revisar
# 21                 totalamountuom  mixta o por revisar
# 22                      isopenbag  mixta o por revisar
# 23             continueinnextdept  mixta o por revisar
# 24                   cancelreason  mixta o por revisar
# 25              statusdescription  mixta o por revisar
# 26              comments_editedby  mixta o por revisar
# 27            comments_canceledby  mixta o por revisar
# 28                  comments_date  mixta o por revisar
# 29                 originalamount  mixta o por revisar
# 30                   originalrate  mixta o por revisar
#
#                                           descripcion
# 0       Identificador interno de la fila en la tabla.
# 1                   Identificador unico del paciente.
# 2             Identificador del ingreso hospitalario.
# 3                Identificador de la estancia en UCI.
# 4                         Tiempo de inicio de evento.
# 5                            Tiempo de fin de evento.
# 6   Codigo del item clinico (se mapea con tablas D...
# 7   Descripcion inferida: revisar documentacion of...
# 8   Descripcion inferida: revisar documentacion of...
# 9   Descripcion inferida: revisar documentacion of...
# 10  Descripcion inferida: revisar documentacion of...
# 11          Timestamp de almacenamiento del registro.
# 12  Identificador del cuidador/profesional que reg...
# 13  Descripcion inferida: revisar documentacion of...
# 14  Descripcion inferida: revisar documentacion of...
# 15  Descripcion inferida: revisar documentacion of...
# 16  Descripcion inferida: revisar documentacion of...
# 17  Descripcion inferida: revisar documentacion of...
# 18  Descripcion inferida: revisar documentacion of...
# 19  Descripcion inferida: revisar documentacion of...
# 20  Descripcion inferida: revisar documentacion of...
# 21  Descripcion inferida: revisar documentacion of...
# 22  Descripcion inferida: revisar documentacion of...
# 23  Descripcion inferida: revisar documentacion of...
# 24  Descripcion inferida: revisar documentacion of...
# 25  Descripcion inferida: revisar documentacion of...
# 26  Descripcion inferida: revisar documentacion of...
# 27  Descripcion inferida: revisar documentacion of...
# 28  Descripcion inferida: revisar documentacion of...
# 29  Descripcion inferida: revisar documentacion of...
# 30  Descripcion inferida: revisar documentacion of...
# ### LABEVENTS
#       columna        tipo_inferido  \
# 0      row_id        identificador
# 1  subject_id        identificador
# 2     hadm_id        identificador
# 3      itemid        identificador
# 4   charttime           fecha/hora
# 5       value     texto/categorica
# 6    valuenum             numerica
# 7    valueuom  mixta o por revisar
# 8        flag  mixta o por revisar
#
#                                          descripcion
# 0      Identificador interno de la fila en la tabla.
# 1                  Identificador unico del paciente.
# 2            Identificador del ingreso hospitalario.
# 3  Codigo del item clinico (se mapea con tablas D...
# 4             Timestamp clinico del evento/medicion.
# 5          Valor textual original de la observacion.
# 6                  Valor numerico de la observacion.
# 7                                  Unidad del valor.
# 8    Bandera del laboratorio (normal/anormal, etc.).
# ### MICROBIOLOGYEVENTS
#                 columna        tipo_inferido  \
# 0                row_id        identificador
# 1            subject_id        identificador
# 2               hadm_id        identificador
# 3             chartdate           fecha/hora
# 4             charttime           fecha/hora
# 5           spec_itemid  mixta o por revisar
# 6        spec_type_desc  mixta o por revisar
# 7            org_itemid  mixta o por revisar
# 8              org_name  mixta o por revisar
# 9           isolate_num  mixta o por revisar
# 10            ab_itemid  mixta o por revisar
# 11              ab_name  mixta o por revisar
# 12        dilution_text  mixta o por revisar
# 13  dilution_comparison  mixta o por revisar
# 14       dilution_value  mixta o por revisar
# 15       interpretation  mixta o por revisar
#
#                                           descripcion
# 0       Identificador interno de la fila en la tabla.
# 1                   Identificador unico del paciente.
# 2             Identificador del ingreso hospitalario.
# 3              Variable temporal del proceso clinico.
# 4              Timestamp clinico del evento/medicion.
# 5   Descripcion inferida: revisar documentacion of...
# 6   Descripcion inferida: revisar documentacion of...
# 7   Descripcion inferida: revisar documentacion of...
# 8   Descripcion inferida: revisar documentacion of...
# 9   Descripcion inferida: revisar documentacion of...
# 10  Descripcion inferida: revisar documentacion of...
# 11  Descripcion inferida: revisar documentacion of...
# 12  Descripcion inferida: revisar documentacion of...
# 13  Descripcion inferida: revisar documentacion of...
# 14  Descripcion inferida: revisar documentacion of...
# 15  Descripcion inferida: revisar documentacion of...
# ### NOTEEVENTS
#         columna        tipo_inferido  \
# 0        row_id        identificador
# 1    subject_id        identificador
# 2       hadm_id        identificador
# 3     chartdate           fecha/hora
# 4     charttime           fecha/hora
# 5     storetime           fecha/hora
# 6      category     texto/categorica
# 7   description  mixta o por revisar
# 8          cgid        identificador
# 9       iserror  mixta o por revisar
# 10         text     texto/categorica
#
#                                           descripcion
# 0       Identificador interno de la fila en la tabla.
# 1                   Identificador unico del paciente.
# 2             Identificador del ingreso hospitalario.
# 3              Variable temporal del proceso clinico.
# 4              Timestamp clinico del evento/medicion.
# 5           Timestamp de almacenamiento del registro.
# 6                     Categoria del evento/nota/item.
# 7   Descripcion inferida: revisar documentacion of...
# 8   Identificador del cuidador/profesional que reg...
# 9   Descripcion inferida: revisar documentacion of...
# 10                      Texto libre (notas clinicas).
# ### OUTPUTEVENTS
#        columna        tipo_inferido  \
# 0       row_id        identificador
# 1   subject_id        identificador
# 2      hadm_id        identificador
# 3   icustay_id        identificador
# 4    charttime           fecha/hora
# 5       itemid        identificador
# 6        value     texto/categorica
# 7     valueuom  mixta o por revisar
# 8    storetime           fecha/hora
# 9         cgid        identificador
# 10     stopped  mixta o por revisar
# 11   newbottle  mixta o por revisar
# 12     iserror  mixta o por revisar
#
#                                           descripcion
# 0       Identificador interno de la fila en la tabla.
# 1                   Identificador unico del paciente.
# 2             Identificador del ingreso hospitalario.
# 3                Identificador de la estancia en UCI.
# 4              Timestamp clinico del evento/medicion.
# 5   Codigo del item clinico (se mapea con tablas D...
# 6           Valor textual original de la observacion.
# 7                                   Unidad del valor.
# 8           Timestamp de almacenamiento del registro.
# 9   Identificador del cuidador/profesional que reg...
# 10  Descripcion inferida: revisar documentacion of...
# 11  Descripcion inferida: revisar documentacion of...
# 12  Descripcion inferida: revisar documentacion of...
# ### PATIENTS
#        columna        tipo_inferido  \
# 0       row_id        identificador
# 1   subject_id        identificador
# 2       gender  mixta o por revisar
# 3          dob           fecha/hora
# 4          dod           fecha/hora
# 5     dod_hosp  mixta o por revisar
# 6      dod_ssn  mixta o por revisar
# 7  expire_flag             numerica
#
#                                          descripcion
# 0      Identificador interno de la fila en la tabla.
# 1                  Identificador unico del paciente.
# 2                                 Sexo del paciente.
# 3                               Fecha de nacimiento.
# 4                                Fecha de defuncion.
# 5  Descripcion inferida: revisar documentacion of...
# 6  Descripcion inferida: revisar documentacion of...
# 7                       Variable binaria indicadora.
# ### PRESCRIPTIONS
#               columna        tipo_inferido  \
# 0              row_id        identificador
# 1          subject_id        identificador
# 2             hadm_id        identificador
# 3          icustay_id        identificador
# 4           startdate           fecha/hora
# 5             enddate           fecha/hora
# 6           drug_type  mixta o por revisar
# 7                drug     texto/categorica
# 8       drug_name_poe  mixta o por revisar
# 9   drug_name_generic  mixta o por revisar
# 10  formulary_drug_cd  mixta o por revisar
# 11                gsn  mixta o por revisar
# 12                ndc  mixta o por revisar
# 13      prod_strength  mixta o por revisar
# 14        dose_val_rx  mixta o por revisar
# 15       dose_unit_rx  mixta o por revisar
# 16      form_val_disp  mixta o por revisar
# 17     form_unit_disp  mixta o por revisar
# 18              route  mixta o por revisar
#
#                                           descripcion
# 0       Identificador interno de la fila en la tabla.
# 1                   Identificador unico del paciente.
# 2             Identificador del ingreso hospitalario.
# 3                Identificador de la estancia en UCI.
# 4              Variable temporal del proceso clinico.
# 5              Variable temporal del proceso clinico.
# 6   Descripcion inferida: revisar documentacion of...
# 7                             Nombre del medicamento.
# 8   Descripcion inferida: revisar documentacion of...
# 9   Descripcion inferida: revisar documentacion of...
# 10  Descripcion inferida: revisar documentacion of...
# 11  Descripcion inferida: revisar documentacion of...
# 12  Descripcion inferida: revisar documentacion of...
# 13  Descripcion inferida: revisar documentacion of...
# 14  Descripcion inferida: revisar documentacion of...
# 15  Descripcion inferida: revisar documentacion of...
# 16  Descripcion inferida: revisar documentacion of...
# 17  Descripcion inferida: revisar documentacion of...
# 18             Via de administracion del medicamento.
# ### PROCEDUREEVENTS_MV
#                        columna        tipo_inferido  \
# 0                       row_id        identificador
# 1                   subject_id        identificador
# 2                      hadm_id        identificador
# 3                   icustay_id        identificador
# 4                    starttime           fecha/hora
# 5                      endtime           fecha/hora
# 6                       itemid        identificador
# 7                        value     texto/categorica
# 8                     valueuom  mixta o por revisar
# 9                     location  mixta o por revisar
# 10            locationcategory  mixta o por revisar
# 11                   storetime           fecha/hora
# 12                        cgid        identificador
# 13                     orderid  mixta o por revisar
# 14                 linkorderid  mixta o por revisar
# 15           ordercategoryname  mixta o por revisar
# 16  secondaryordercategoryname  mixta o por revisar
# 17    ordercategorydescription  mixta o por revisar
# 18                   isopenbag  mixta o por revisar
# 19          continueinnextdept  mixta o por revisar
# 20                cancelreason  mixta o por revisar
# 21           statusdescription  mixta o por revisar
# 22           comments_editedby  mixta o por revisar
# 23         comments_canceledby  mixta o por revisar
# 24               comments_date  mixta o por revisar
#
#                                           descripcion
# 0       Identificador interno de la fila en la tabla.
# 1                   Identificador unico del paciente.
# 2             Identificador del ingreso hospitalario.
# 3                Identificador de la estancia en UCI.
# 4                         Tiempo de inicio de evento.
# 5                            Tiempo de fin de evento.
# 6   Codigo del item clinico (se mapea con tablas D...
# 7           Valor textual original de la observacion.
# 8                                   Unidad del valor.
# 9   Descripcion inferida: revisar documentacion of...
# 10  Descripcion inferida: revisar documentacion of...
# 11          Timestamp de almacenamiento del registro.
# 12  Identificador del cuidador/profesional que reg...
# 13  Descripcion inferida: revisar documentacion of...
# 14  Descripcion inferida: revisar documentacion of...
# 15  Descripcion inferida: revisar documentacion of...
# 16  Descripcion inferida: revisar documentacion of...
# 17  Descripcion inferida: revisar documentacion of...
# 18  Descripcion inferida: revisar documentacion of...
# 19  Descripcion inferida: revisar documentacion of...
# 20  Descripcion inferida: revisar documentacion of...
# 21  Descripcion inferida: revisar documentacion of...
# 22  Descripcion inferida: revisar documentacion of...
# 23  Descripcion inferida: revisar documentacion of...
# 24  Descripcion inferida: revisar documentacion of...
# ### PROCEDURES_ICD
#       columna        tipo_inferido  \
# 0      row_id        identificador
# 1  subject_id        identificador
# 2     hadm_id        identificador
# 3     seq_num  mixta o por revisar
# 4   icd9_code  mixta o por revisar
#
#                                          descripcion
# 0      Identificador interno de la fila en la tabla.
# 1                  Identificador unico del paciente.
# 2            Identificador del ingreso hospitalario.
# 3  Descripcion inferida: revisar documentacion of...
# 4            Codigo ICD-9 diagnostico/procedimiento.
# ### SERVICES
#         columna        tipo_inferido  \
# 0        row_id        identificador
# 1    subject_id        identificador
# 2       hadm_id        identificador
# 3  transfertime           fecha/hora
# 4  prev_service  mixta o por revisar
# 5  curr_service  mixta o por revisar
#
#                                          descripcion
# 0      Identificador interno de la fila en la tabla.
# 1                  Identificador unico del paciente.
# 2            Identificador del ingreso hospitalario.
# 3             Variable temporal del proceso clinico.
# 4  Descripcion inferida: revisar documentacion of...
# 5  Descripcion inferida: revisar documentacion of...
# ### TRANSFERS
#           columna        tipo_inferido  \
# 0          row_id        identificador
# 1      subject_id        identificador
# 2         hadm_id        identificador
# 3      icustay_id        identificador
# 4        dbsource  mixta o por revisar
# 5       eventtype  mixta o por revisar
# 6   prev_careunit  mixta o por revisar
# 7   curr_careunit  mixta o por revisar
# 8     prev_wardid  mixta o por revisar
# 9     curr_wardid  mixta o por revisar
# 10         intime           fecha/hora
# 11        outtime           fecha/hora
# 12            los             numerica
#
#                                           descripcion
# 0       Identificador interno de la fila en la tabla.
# 1                   Identificador unico del paciente.
# 2             Identificador del ingreso hospitalario.
# 3                Identificador de la estancia en UCI.
# 4             Sistema de origen (CareVue/MetaVision).
# 5   Descripcion inferida: revisar documentacion of...
# 6   Descripcion inferida: revisar documentacion of...
# 7   Descripcion inferida: revisar documentacion of...
# 8   Descripcion inferida: revisar documentacion of...
# 9   Descripcion inferida: revisar documentacion of...
# 10                         Inicio de estancia en UCI.
# 11                            Fin de estancia en UCI.
# 12             Length of stay (duracion de estancia).

# %% [markdown]
# ## 3) Estrategia de integracion para dataset analitico
#
# Para entrenamiento clasico de ML, conviene construir una tabla por estancia en UCI (una fila por `icustay_id`) o por admision (`hadm_id`).
#
# En este cuadernillo construiremos una base por `icustay_id`, uniendo:
#
# - `PATIENTS` + `ADMISSIONS` + `ICUSTAYS` (nucleo demografico/episodio).
# - Agregados de `LABEVENTS` (estadisticos por ingreso).
# - Agregados de `PRESCRIPTIONS` (conteos de farmacos y vias).
# - Agregados de codigos (`DIAGNOSES_ICD`, `PROCEDURES_ICD`).
#
# Esto mantiene trazabilidad clinica y reduce dimensionalidad.

# %%
# Carga de tablas core
patients = pd.read_csv('PATIENTS.csv', parse_dates=['dob','dod','dod_hosp','dod_ssn'])
adm = pd.read_csv('ADMISSIONS.csv', parse_dates=['admittime','dischtime','deathtime','edregtime','edouttime'])
icu = pd.read_csv('ICUSTAYS.csv', parse_dates=['intime','outtime'])

core = (
    icu.merge(adm, on=['subject_id','hadm_id'], how='left', suffixes=('_icu','_adm'))
       .merge(patients[['subject_id','gender','dob','dod','expire_flag']], on='subject_id', how='left')
)

# Edad al ingreso (controlando edades negativas por problemas de fecha)
core['age_years'] = (core['admittime'] - core['dob']).dt.days / 365.25
core.loc[core['age_years'] < 0, 'age_years'] = np.nan

# Duraciones en horas
core['icu_los_hours'] = (core['outtime'] - core['intime']).dt.total_seconds() / 3600.0
core['hosp_los_hours'] = (core['dischtime'] - core['admittime']).dt.total_seconds() / 3600.0

core.shape, core[['subject_id','hadm_id','icustay_id']].drop_duplicates().shape
# Out:
# ((136, 36), (136, 3))

# %%
# Agregados de laboratorio por hadm_id
labs = pd.read_csv('LABEVENTS.csv', usecols=['hadm_id','itemid','valuenum'])
labs = labs.dropna(subset=['hadm_id'])

lab_agg = labs.groupby('hadm_id').agg(
    lab_n=('valuenum','count'),
    lab_mean=('valuenum','mean'),
    lab_std=('valuenum','std'),
    lab_min=('valuenum','min'),
    lab_max=('valuenum','max'),
    lab_item_unique=('itemid','nunique')
).reset_index()

# Agregados de prescripciones por hadm_id
rx = pd.read_csv('PRESCRIPTIONS.csv', usecols=['hadm_id','drug','route'])
rx = rx.dropna(subset=['hadm_id'])
rx_agg = rx.groupby('hadm_id').agg(
    rx_n=('drug','count'),
    rx_drug_unique=('drug','nunique'),
    rx_route_unique=('route','nunique')
).reset_index()

# Agregados de codigos diagnosticos/procedimientos por hadm_id
diag = pd.read_csv('DIAGNOSES_ICD.csv', usecols=['hadm_id','icd9_code'])
proc = pd.read_csv('PROCEDURES_ICD.csv', usecols=['hadm_id','icd9_code'])

diag_agg = diag.groupby('hadm_id').agg(diag_code_n=('icd9_code','nunique')).reset_index()
proc_agg = proc.groupby('hadm_id').agg(proc_code_n=('icd9_code','nunique')).reset_index()

# Merge final de agregados
df = (core
      .merge(lab_agg, on='hadm_id', how='left')
      .merge(rx_agg, on='hadm_id', how='left')
      .merge(diag_agg, on='hadm_id', how='left')
      .merge(proc_agg, on='hadm_id', how='left'))

df.shape
# Out:
# (136, 47)

# %% [markdown]
# ## 4) Transformaciones a numerico: que cambios se hacen y por que
#
# A continuacion aplicamos transformaciones estandar para ML:
#
# 1. **Fechas -> variables numericas derivadas**
#    - Ya derivamos `age_years`, `icu_los_hours`, `hosp_los_hours`.
#    - Motivo: los modelos tabulares trabajan mejor con magnitudes numericas directamente interpretables.
#
# 2. **Texto/categoricas -> codificacion numerica**
#    - One-hot para columnas de baja/media cardinalidad (`gender`, `admission_type`, etc.).
#    - Motivo: evita imponer orden artificial y permite que el modelo use categorias de forma no ordinal.
#
# 3. **Valores faltantes**
#    - Mediana para numericas, categoria mas frecuente para categoricas.
#    - Motivo: mantener filas y evitar sesgos por eliminacion agresiva.
#
# 4. **Escalado numerico**
#    - `StandardScaler` para modelos sensibles a escala (regresion logistica, redes neuronales).
#
# 5. **Reduccion de dimensionalidad indirecta**
#    - En lugar de usar millones de filas crudas de eventos, agregamos estadisticos por admision.
#    - Motivo: convertir series/eventos en resumenes robustos y computacionalmente tratables.

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.metrics import roc_auc_score, classification_report, mean_absolute_error, r2_score
from sklearn.linear_model import LogisticRegression, LinearRegression

# Targets de ejemplo
target_cls = 'hospital_expire_flag'   # clasificacion binaria
target_reg = 'icu_los_hours'          # regresion

# Seleccion de columnas candidatas
drop_cols = [
    'row_id_icu','row_id_adm','subject_id','hadm_id','icustay_id',
    'dob','dod','dod_hosp','dod_ssn','admittime','dischtime','deathtime','intime','outtime',
    'edregtime','edouttime',
]

feature_df = df.copy()
existing_drop = [c for c in drop_cols if c in feature_df.columns]
feature_df = feature_df.drop(columns=existing_drop)

# Quitamos columnas de texto libre no controlado para baseline
for c in ['diagnosis']:
    if c in feature_df.columns:
        feature_df = feature_df.drop(columns=[c])

# Filtrar filas con target disponible
cls_df = feature_df.dropna(subset=[target_cls]).copy()
reg_df = feature_df.dropna(subset=[target_reg]).copy()

num_cols = cls_df.select_dtypes(include=[np.number]).columns.tolist()
cat_cols = cls_df.select_dtypes(exclude=[np.number]).columns.tolist()
for t in [target_cls, target_reg]:
    if t in num_cols:
        num_cols.remove(t)
    if t in cat_cols:
        cat_cols.remove(t)

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

preprocess = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, num_cols),
        ('cat', categorical_transformer, cat_cols)
    ]
)

len(num_cols), len(cat_cols), cls_df.shape, reg_df.shape
# Out:
# (18, 12, (136, 32), (136, 32))

# %%
## Baseline de clasificacion: mortalidad hospitalaria
X_cls = cls_df.drop(columns=[target_cls])
y_cls = cls_df[target_cls].astype(int)

Xc_train, Xc_test, yc_train, yc_test = train_test_split(
    X_cls, y_cls, test_size=0.2, random_state=42, stratify=y_cls
)

clf = Pipeline(steps=[
    ('preprocess', preprocess),
    ('model', LogisticRegression(max_iter=200))
])

clf.fit(Xc_train, yc_train)
yc_pred = clf.predict(Xc_test)
yc_prob = clf.predict_proba(Xc_test)[:, 1]

print('AUC:', roc_auc_score(yc_test, yc_prob))
print(classification_report(yc_test, yc_pred))
# Out:
# AUC: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00         9
#
#     accuracy                           1.00        28
#    macro avg       1.00      1.00      1.00        28
# weighted avg       1.00      1.00      1.00        28

# %%
## Baseline de regresion: duracion de estancia UCI (horas)
X_reg = reg_df.drop(columns=[target_reg])
y_reg = reg_df[target_reg]

Xr_train, Xr_test, yr_train, yr_test = train_test_split(
    X_reg, y_reg, test_size=0.2, random_state=42
)

reg = Pipeline(steps=[
    ('preprocess', preprocess),
    ('model', LinearRegression())
])

reg.fit(Xr_train, yr_train)
yr_pred = reg.predict(Xr_test)

print('MAE:', mean_absolute_error(yr_test, yr_pred))
print('R2 :', r2_score(yr_test, yr_pred))
# Out:
# MAE: 0.0007579606162665239
# R2 : 0.9999999998625991

# %% [markdown]
# ## 5) Preparacion para redes neuronales
#
# Para redes neuronales tabulares (MLP), puedes reutilizar el mismo `preprocess` y luego:
#
# - convertir la matriz transformada a `float32`,
# - entrenar un modelo denso en TensorFlow/PyTorch,
# - usar early stopping,
# - balancear clases si el target esta desbalanceado.
#
# Ejemplo orientativo (no ejecuta entrenamiento pesado por defecto):

# %%
# Ejemplo de conversion para red neuronal (clasificacion)
# Requiere: pip install tensorflow

# X_train_nn = preprocess.fit_transform(Xc_train)
# X_test_nn  = preprocess.transform(Xc_test)
# y_train_nn = yc_train.values.astype('float32')
# y_test_nn  = yc_test.values.astype('float32')

# Si el transformador devuelve sparse matrix:
# X_train_nn = X_train_nn.toarray().astype('float32')
# X_test_nn = X_test_nn.toarray().astype('float32')

# import tensorflow as tf
# model = tf.keras.Sequential([
#     tf.keras.layers.Input(shape=(X_train_nn.shape[1],)),
#     tf.keras.layers.Dense(256, activation='relu'),
#     tf.keras.layers.Dropout(0.3),
#     tf.keras.layers.Dense(64, activation='relu'),
#     tf.keras.layers.Dense(1, activation='sigmoid')
# ])
# model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['AUC'])
# model.fit(X_train_nn, y_train_nn, validation_split=0.2, epochs=20, batch_size=256)
# model.evaluate(X_test_nn, y_test_nn)

# %% [markdown]
# ## 6) Resumen de transformaciones aplicadas (trazabilidad)
#
# Transformaciones realizadas en este cuadernillo:
#
# - Join por claves clinicas: `subject_id`, `hadm_id`, `icustay_id`.
# - Fechas a duraciones/edad numerica: `age_years`, `icu_los_hours`, `hosp_los_hours`.
# - Agregacion de eventos de alta frecuencia (labs, prescripciones, ICD) a estadisticos por admision.
# - Imputacion de faltantes: mediana (numericas), moda (categoricas).
# - Codificacion de categoricas: one-hot.
# - Escalado de numericas: estandarizacion.
#
# Con esto, la base queda lista para experimentar con modelos de regresion, clasificacion y redes neuronales tabulares.

# %% [markdown]
# ## 7) Bitacora explicita de cambios de transformacion
#
# Esta seccion deja una tabla clara de **que se transforma, como y por que**, para documentacion y reporte metodologico.

# %%
transform_log = []

for c in num_cols:
    transform_log.append({
        'columna': c,
        'tipo_original': 'numerica',
        'transformacion': 'imputacion_mediana + escalado_estandar',
        'motivo': 'manejar faltantes y homogeneizar escala para modelos lineales/NN'
    })

for c in cat_cols:
    transform_log.append({
        'columna': c,
        'tipo_original': 'categorica/texto corto',
        'transformacion': 'imputacion_moda + one_hot_encoding',
        'motivo': 'convertir categorias a formato numerico sin orden artificial'
    })

# Variables derivadas de fechas y su justificacion
for c, why in [
    ('age_years', 'representar edad en formato numerico interpretable'),
    ('icu_los_hours', 'objetivo/feature continua para tareas de regresion'),
    ('hosp_los_hours', 'capturar severidad/consumo de recursos en horas')
]:
    if c in df.columns:
        transform_log.append({
            'columna': c,
            'tipo_original': 'derivada temporal',
            'transformacion': 'ingenieria_de_variables_desde_fechas',
            'motivo': why
        })

transform_log_df = pd.DataFrame(transform_log).sort_values(['tipo_original','columna']).reset_index(drop=True)
transform_log_df.head(30)
# Out:
#                  columna           tipo_original  \
# 0     admission_location  categorica/texto corto
# 1         admission_type  categorica/texto corto
# 2               dbsource  categorica/texto corto
# 3     discharge_location  categorica/texto corto
# 4              ethnicity  categorica/texto corto
# 5         first_careunit  categorica/texto corto
# 6                 gender  categorica/texto corto
# 7              insurance  categorica/texto corto
# 8               language  categorica/texto corto
# 9          last_careunit  categorica/texto corto
# 10        marital_status  categorica/texto corto
# 11              religion  categorica/texto corto
# 12             age_years       derivada temporal
# 13        hosp_los_hours       derivada temporal
# 14         icu_los_hours       derivada temporal
# 15             age_years                numerica
# 16           diag_code_n                numerica
# 17           expire_flag                numerica
# 18          first_wardid                numerica
# 19  has_chartevents_data                numerica
# 20        hosp_los_hours                numerica
# 21       lab_item_unique                numerica
# 22               lab_max                numerica
# 23              lab_mean                numerica
# 24               lab_min                numerica
# 25                 lab_n                numerica
# 26               lab_std                numerica
# 27           last_wardid                numerica
# 28                   los                numerica
# 29           proc_code_n                numerica
#
#                             transformacion  \
# 0       imputacion_moda + one_hot_encoding
# 1       imputacion_moda + one_hot_encoding
# 2       imputacion_moda + one_hot_encoding
# 3       imputacion_moda + one_hot_encoding
# 4       imputacion_moda + one_hot_encoding
# 5       imputacion_moda + one_hot_encoding
# 6       imputacion_moda + one_hot_encoding
# 7       imputacion_moda + one_hot_encoding
# 8       imputacion_moda + one_hot_encoding
# 9       imputacion_moda + one_hot_encoding
# 10      imputacion_moda + one_hot_encoding
# 11      imputacion_moda + one_hot_encoding
# 12    ingenieria_de_variables_desde_fechas
# 13    ingenieria_de_variables_desde_fechas
# 14    ingenieria_de_variables_desde_fechas
# 15  imputacion_mediana + escalado_estandar
# 16  imputacion_mediana + escalado_estandar
# 17  imputacion_mediana + escalado_estandar
# 18  imputacion_mediana + escalado_estandar
# 19  imputacion_mediana + escalado_estandar
# 20  imputacion_mediana + escalado_estandar
# 21  imputacion_mediana + escalado_estandar
# 22  imputacion_mediana + escalado_estandar
# 23  imputacion_mediana + escalado_estandar
# 24  imputacion_mediana + escalado_estandar
# 25  imputacion_mediana + escalado_estandar
# 26  imputacion_mediana + escalado_estandar
# 27  imputacion_mediana + escalado_estandar
# 28  imputacion_mediana + escalado_estandar
# 29  imputacion_mediana + escalado_estandar
#
#                                                motivo
# 0   convertir categorias a formato numerico sin or...
# 1   convertir categorias a formato numerico sin or...
# 2   convertir categorias a formato numerico sin or...
# 3   convertir categorias a formato numerico sin or...
# 4   convertir categorias a formato numerico sin or...
# 5   convertir categorias a formato numerico sin or...
# 6   convertir categorias a formato numerico sin or...
# 7   convertir categorias a formato numerico sin or...
# 8   convertir categorias a formato numerico sin or...
# 9   convertir categorias a formato numerico sin or...
# 10  convertir categorias a formato numerico sin or...
# 11  convertir categorias a formato numerico sin or...
# 12  representar edad en formato numerico interpret...
# 13    capturar severidad/consumo de recursos en horas
# 14  objetivo/feature continua para tareas de regre...
# 15  manejar faltantes y homogeneizar escala para m...
# 16  manejar faltantes y homogeneizar escala para m...
# 17  manejar faltantes y homogeneizar escala para m...
# 18  manejar faltantes y homogeneizar escala para m...
# 19  manejar faltantes y homogeneizar escala para m...
# 20  manejar faltantes y homogeneizar escala para m...
# 21  manejar faltantes y homogeneizar escala para m...
# 22  manejar faltantes y homogeneizar escala para m...
# 23  manejar faltantes y homogeneizar escala para m...
# 24  manejar faltantes y homogeneizar escala para m...
# 25  manejar faltantes y homogeneizar escala para m...
# 26  manejar faltantes y homogeneizar escala para m...
# 27  manejar faltantes y homogeneizar escala para m...
# 28  manejar faltantes y homogeneizar escala para m...
# 29  manejar faltantes y homogeneizar escala para m...

# %%
display(transform_log_df)
print('Total de columnas documentadas:', len(transform_log_df))
# Out:
#                  columna           tipo_original  \
# 0     admission_location  categorica/texto corto
# 1         admission_type  categorica/texto corto
# 2               dbsource  categorica/texto corto
# 3     discharge_location  categorica/texto corto
# 4              ethnicity  categorica/texto corto
# 5         first_careunit  categorica/texto corto
# 6                 gender  categorica/texto corto
# 7              insurance  categorica/texto corto
# 8               language  categorica/texto corto
# 9          last_careunit  categorica/texto corto
# 10        marital_status  categorica/texto corto
# 11              religion  categorica/texto corto
# 12             age_years       derivada temporal
# 13        hosp_los_hours       derivada temporal
# 14         icu_los_hours       derivada temporal
# 15             age_years                numerica
# 16           diag_code_n                numerica
# 17           expire_flag                numerica
# 18          first_wardid                numerica
# 19  has_chartevents_data                numerica
# 20        hosp_los_hours                numerica
# 21       lab_item_unique                numerica
# 22               lab_max                numerica
# 23              lab_mean                numerica
# 24               lab_min                numerica
# 25                 lab_n                numerica
# 26               lab_std                numerica
# 27           last_wardid                numerica
# 28                   los                numerica
# 29           proc_code_n                numerica
# 30        rx_drug_unique                numerica
# 31                  rx_n                numerica
# 32       rx_route_unique                numerica
#
#                             transformacion  \
# 0       imputacion_moda + one_hot_encoding
# 1       imputacion_moda + one_hot_encoding
# 2       imputacion_moda + one_hot_encoding
# 3       imputacion_moda + one_hot_encoding
# 4       imputacion_moda + one_hot_encoding
# 5       imputacion_moda + one_hot_encoding
# 6       imputacion_moda + one_hot_encoding
# 7       imputacion_moda + one_hot_encoding
# 8       imputacion_moda + one_hot_encoding
# 9       imputacion_moda + one_hot_encoding
# 10      imputacion_moda + one_hot_encoding
# 11      imputacion_moda + one_hot_encoding
# 12    ingenieria_de_variables_desde_fechas
# 13    ingenieria_de_variables_desde_fechas
# 14    ingenieria_de_variables_desde_fechas
# 15  imputacion_mediana + escalado_estandar
# 16  imputacion_mediana + escalado_estandar
# 17  imputacion_mediana + escalado_estandar
# 18  imputacion_mediana + escalado_estandar
# 19  imputacion_mediana + escalado_estandar
# 20  imputacion_mediana + escalado_estandar
# 21  imputacion_mediana + escalado_estandar
# 22  imputacion_mediana + escalado_estandar
# 23  imputacion_mediana + escalado_estandar
# 24  imputacion_mediana + escalado_estandar
# 25  imputacion_mediana + escalado_estandar
# 26  imputacion_mediana + escalado_estandar
# 27  imputacion_mediana + escalado_estandar
# 28  imputacion_mediana + escalado_estandar
# 29  imputacion_mediana + escalado_estandar
# 30  imputacion_mediana + escalado_estandar
# 31  imputacion_mediana + escalado_estandar
# 32  imputacion_mediana + escalado_estandar
#
#                                                motivo
# 0   convertir categorias a formato numerico sin or...
# 1   convertir categorias a formato numerico sin or...
# 2   convertir categorias a formato numerico sin or...
# 3   convertir categorias a formato numerico sin or...
# 4   convertir categorias a formato numerico sin or...
# 5   convertir categorias a formato numerico sin or...
# 6   convertir categorias a formato numerico sin or...
# 7   convertir categorias a formato numerico sin or...
# 8   convertir categorias a formato numerico sin or...
# 9   convertir categorias a formato numerico sin or...
# 10  convertir categorias a formato numerico sin or...
# 11  convertir categorias a formato numerico sin or...
# 12  representar edad en formato numerico interpret...
# 13    capturar severidad/consumo de recursos en horas
# 14  objetivo/feature continua para tareas de regre...
# 15  manejar faltantes y homogeneizar escala para m...
# 16  manejar faltantes y homogeneizar escala para m...
# 17  manejar faltantes y homogeneizar escala para m...
# 18  manejar faltantes y homogeneizar escala para m...
# 19  manejar faltantes y homogeneizar escala para m...
# 20  manejar faltantes y homogeneizar escala para m...
# 21  manejar faltantes y homogeneizar escala para m...
# 22  manejar faltantes y homogeneizar escala para m...
# 23  manejar faltantes y homogeneizar escala para m...
# 24  manejar faltantes y homogeneizar escala para m...
# 25  manejar faltantes y homogeneizar escala para m...
# 26  manejar faltantes y homogeneizar escala para m...
# 27  manejar faltantes y homogeneizar escala para m...
# 28  manejar faltantes y homogeneizar escala para m...
# 29  manejar faltantes y homogeneizar escala para m...
# 30  manejar faltantes y homogeneizar escala para m...
# 31  manejar faltantes y homogeneizar escala para m...
# 32  manejar faltantes y homogeneizar escala para m...
# Total de columnas documentadas: 33
